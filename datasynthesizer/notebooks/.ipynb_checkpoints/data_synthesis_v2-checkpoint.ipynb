# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import secrets
import uuid
from random import randrange
from datetime import timedelta, datetime


fake = Faker()
fake.seed_instance(8)
random.seed(8)

# %%
{
    "eventId": "244ca386-89a5-4b7e-8ac4-4b7dd4fee74e",
    "eventTimestamp": "11/12/2022 08:20:43",
    "dataSource": "app",
    "healthState": "good",
    "generalHealthStats": {
        "stepCount": 4000,
        "stress": 3,
        "bloodOxygen": 95,
        "sleepHours": 8,
        "REMsleepHours": 4,
        "caloriesBurnt": 2000
    },
    "user": {
        "user_id": "fdde5bd5-1146-48df-94ef-d56532290901",
        "firstname": "john",
        "lastname": "doe",
        "gender": "male",
        "age": 23,
        "weight": 88,
        "height": 176
    },
    "vitals": {
        "heartRate": 72,
        "systolicBloodPressure": 130,
        "diastolicBloodPressure": 70,
        "bodyTemperature": 98.6,
        "breathingFrequency": 15
    }
}
# Out:
# {'eventId': '244ca386-89a5-4b7e-8ac4-4b7dd4fee74e',
#  'eventTimestamp': '11/12/2022 08:20:43',
#  'dataSource': 'app',
#  'healthState': 'good',
#  'generalHealthStats': {'stepCount': 4000,
#   'stress': 3,
#   'bloodOxygen': 95,
#   'sleepHours': 8,
#   'REMsleepHours': 4,
#   'caloriesBurnt': 2000},
#  'user': {'user_id': 'fdde5bd5-1146-48df-94ef-d56532290901',
#   'firstname': 'john',
#   'lastname': 'doe',
#   'gender': 'male',
#   'age': 23,
#   'weight': 88,
#   'height': 176},
#  'vitals': {'heartRate': 72,
#   'systolicBloodPressure': 130,
#   'diastolicBloodPressure': 70,
#   'bodyTemperature': 98.6,
#   'breathingFrequency': 15}}

# %%
def fetch_random_date(start, end):
    """
        This function will return a random datetime between two datetime 
        objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
# take existing user ids
    # for only those users
        # generate timestamps appropriately within a range
        # generate vitals such that they increase together (define ranges)
        # generate label according to vitals - only for outliers

# %%
users = ['d96c2414-cbfa-462e-9851-c2163242c804', '0e2975b0-c8f5-47f5-870b-91e31b667aa4', '83e13045-de5a-471f-8a07-84dcca9ca93d', '37f86216-dfe2-4796-bcb0-b05a01346b67', '7ffe75be-1e87-4c77-a692-c64f5c195c2c', '23e41df1-6a1c-4b7d-ad6c-e541bc05e91c', 'e531f398-b542-44ec-9731-e7767c141145', '6c594fd7-3357-466f-b4a2-c3058fea4ea2', '37e18480-205a-4255-b908-a326f4fcf955', '3c52d060-8a7e-4f42-8ed4-663ec8439186', 'da57f00b-65ed-439c-8c47-f9974b1708ba', '599d4f49-f5c7-4d0b-8346-45d06598ca2d', '8496a8d8-0bf2-469e-adc3-302932490e8d', '8c076298-54fb-484a-a84d-4abec6980a1a', '44f0d53c-7d24-48a2-996e-2e35d90c9376', 'a22a05b9-91be-43d6-b2dc-0654385fa819', '99314929-ea88-4202-b3cd-92936ab6995b', '90f9cbca-71c6-437f-9120-834ea8be9fb3', '949be74f-fff2-452a-b5d5-e26b1462d2a2', 'e5c9695f-2931-42cb-9feb-dba51f57f962', '0f34315f-2588-4164-b8e4-c96ea059a2ec', '421dcf92-8390-493d-bf67-935cd45404ad', 'ff0082c7-7ce0-4bdb-ada7-6ee77e0f1339', '1b8a9ed7-f030-4aa7-b1e0-14a6105519d0', '7868c062-7d90-44fa-b310-2149410e15b3', '069fd4fa-6a22-4859-9200-801af3b4e1a9', 'df4c6022-5110-4b98-9d4a-3951e55617e9', '0b4c8bc9-3082-4aa3-a765-f3b1b3abb1a0', 'c4ff77ef-8fd5-4db7-970c-c8c89418bd2a', '1b887cc3-7609-43a8-b459-b49311582903', 'dccdf1a0-8423-4f1c-8e12-745797e78b9c', '73aa6f46-2d0e-48e0-b53b-9e404ebe2ff0', 'f3d3bf56-e392-4ccf-bcd8-c43e9470bafb', '9a46749e-d528-422a-ba09-86913ac12120', '3102c277-7175-4935-bd7c-151f91c7db9f', '754d104c-3f5c-44ae-a573-93563907ba32', 'afc3f0d0-6d72-4b08-86e4-da4f1a4c3ad5', 'e93dd171-a16a-489d-95e9-fbf754a81929', 'e077ee51-8511-4a74-a454-1ef96b18b120', '6e3923d3-eb6a-4a1c-95b4-d7b0e5456322', '5ede3316-3ac7-47f8-88f3-81db9be88bc8', '12d2d560-9e04-44d8-822d-6082e21ec1cd', '581a6ef0-8b9e-46a1-bc7d-20f6ee0097a0', '6fb88685-8611-453d-ba7e-f7005b692645', '6efa7c38-8a85-4e31-bb23-b8f7c18ada51', '304db447-0e31-4296-b863-ae0789c39361', 'ed06e24c-22f8-4da0-ad43-a7b8863c9b08', '0ed24f4d-db76-4935-935c-f207f579dfdf', '5f4806f0-7e62-4f07-b54b-6bf15960eee8', '9c0797ad-d81e-4459-bab7-30b249771721', '8800321d-2ce6-40f0-9ef3-955175d2be33', 'ee51ed65-46d2-4bda-b18f-a73b84225d2f', 'aa8662c2-ea5d-4828-93cc-f326a377c156', 'd4b116e8-19e1-4e7a-87da-4d218897ad98', '95f40700-3613-4c21-ac06-472bc6b8eec6', '42dd56a1-4f9f-4af7-a633-74b4ecd4d929', '5b76e44d-449d-4612-ad23-33afd93b8cf1', '6ce8face-2016-41f6-997e-c21885300d75', '301c163d-3d27-4d74-b4d6-29a53958d3b1', '5ac5935d-3cb9-4502-8388-043f915bed4f', 'ae4fef12-aef8-45ac-8114-122bf69b17d3', '00fcb56c-ba09-4271-8e06-509018076a7b', '849c8b16-3ed9-4560-9c7e-47151cc06492', 'b89be88a-08ae-4380-920a-d3d567f06387', '56974704-4750-4bf4-bfc2-c32259c44651', '6254f57f-092a-4ebf-81bb-52f2862e64f5', '0140fd4a-bf1a-43ed-a0bc-339c25303eb4', '155d6930-15ef-439c-bbbd-fdf5abf4ace1', 'c53f29b8-9746-49a9-9f29-30781d6787cc', '17a63d7b-10fa-4cc6-8a44-4418b2ada636', '3e72fa78-91ba-4cbd-87cf-e5d1790ca232', '4a39dc62-d61c-4a0c-b057-44c52e010d1f', '8efda804-3bd3-4907-b585-2557f6067731', '8d9bd4e2-0db1-41d6-bdbb-b8f671340a23', 'c6caf36e-1c0f-4da6-b203-fff75abaee87', '741fa25b-a09f-4247-9cad-39560c591bc7', '3819dd91-65c9-4831-8605-ecdfe2f8e1f7', '24181ae4-b4eb-4574-b1e7-019c4e141efc', 'b8abbea7-d48e-4c22-af41-afecc61dfdfd', 'f56b11de-b7a1-47c9-a742-e5a030d23897', '2ae10cc2-df6e-4c52-87a9-d2663f836676', '5876fdc9-aa3e-40c4-b900-2a3b217ab185', '73e42ff9-adad-4d98-9d2a-533e77700eb9', 'd6d9ac4e-dbef-43ea-a369-9d0a19add98f', 'e5454dff-e9a4-4531-8ed8-dd8bdd7ad615', '6ffda261-cc5c-4d11-af74-ab15f9f1539f', '0f51e3f2-1782-4113-94a1-c10fe0080f5f', '7c1381bb-5972-4ad4-b67c-8514e01d9bc9', '334e6a62-26a7-42fb-8f36-4189d55d9b0e', '1f0a2cbd-372f-4fec-8ed3-964a2c307543', '8441e70d-9ac2-4c05-b96c-52c970c5f83a', 'bec2fca4-bff3-4212-968a-2eb27dd77374', '55f11a04-2a89-457d-8b47-aaf3b4568086', '012a36ff-bf7d-48d8-986e-5868928f9303', 'dd1bf8b8-2ec1-4a7f-af09-89a22f39cb2d', 'c41ebd32-9a72-48c7-b35d-d56fb39b71d1', '4c513614-cfcb-413e-91d6-9bce88dd7436', 'c01db9d5-798d-493d-97cf-e08e76596ef5', 'df285b4f-0506-46a4-af60-676e30a575ac', '82542a00-1570-474c-b6ae-7de5b65c0433', 'aec0bc18-3c71-4a5c-a035-4f471227cab3', '9a72283f-8a2f-4183-828c-48080d052ebd', 'ebd2bf89-fd4f-4840-bb99-cc81d99011e6', 'af2d53cd-d583-4995-ab8f-5bf7a7797422', '59948437-21ea-47f4-a28b-f53bd290c482', '610f5bcb-ce41-469f-9449-ab63a4e00c09', 'c08613b9-6759-4af5-9f8c-4c26d7f02b26', 'd7753476-ad8c-482c-a737-032420229ffd', '6d219066-96fe-4b30-9bd0-8026b46f10d6', 'e9e7b776-a39a-45ae-b0c2-2dd655d4f817', 'd1577494-884b-4699-a4ff-15204e8cb23b', '47baa448-a53c-4411-8017-0a09e9dd022f', '6578607c-f52a-4043-b557-4268f2780f5c', '3283a4e6-c3d3-4f15-a3d3-85d23e8788c1', 'dd6f4320-5ce1-4d93-b269-c82544fe025c', '83d5eec2-2bff-4f13-a131-23ec66a6afcd', '498dc082-da68-45ea-a531-ae0fd8582bce', '582d79af-fe6d-420e-a96a-0cbba1e6f160', '5ac168b6-5362-46bb-ae75-03dc0dde5939', '1ba26536-14fc-49b4-b268-c8c8d13f31b3', '319e792b-11b6-4e29-87c6-6530dba415fc', 'd678e800-a808-4aea-a0de-7a8fd6e29b18', '1b901a26-f8ec-4fcc-91a5-779772dfaf05', '1a9be60c-4225-48e6-b3bd-d5f68a329df8', 'bcb64fcf-ad4a-497c-b6da-f4258e99ebc4', 'a0b2c8d9-4903-433e-9612-bd4385a458fb', '026bf44c-af0d-4ebe-b569-a712881767b6', '7805d7e9-b97d-4350-8047-87a51ab6543f', '1dbd4605-80e4-43e7-9502-c15ef9147279', '6c995b76-437e-4edb-971a-ecf3ef93a231', '5337cbc5-696c-4eab-8927-416e24e71a4b', 'e63ea6f8-e2fc-439f-a771-6553c62142ed', '901a0f70-0729-47e5-b56a-298d07cfd413', 'abfad4c2-2f31-4d3c-afd3-90b3173d830b', '896cfbe4-48b7-4b5b-ae29-850acea16e7d', '4e3a2923-6df6-4a0c-b0a3-6797ba37e4b4', '398374df-6c89-424a-9202-9606b0a7f8b3', '1b555780-2021-4638-bab2-ccf6ce2ff281', '6fe824a4-5ed4-451b-bd41-269a276dde7a', 'b0c9bc11-f856-44a1-b2f1-8cfea0f014b5', 'b89ba94a-aa8d-461b-ae8f-2bfbc63b1436', 'c375133d-7ddb-4924-a37c-17bd7d5e69a9', '39e82c54-25d6-4669-b26f-1c7e88898430', 'e9b6f490-f41b-4a07-a08b-abccb637f64e', '311de30d-c8b7-410f-8caa-66c2e75140ba', '04eee26f-98b1-47ba-aa27-aabc4142b491', '06d341bb-b737-4e1c-9091-3294ae2a72a3', '3ed70a1c-3ae3-4ec9-8c9d-00d53ab714d2', 'd34a8162-b8c6-4076-946d-fe71ca899f3a', '2ab1f551-350a-420e-8899-00dd99f099ef', '5befa52e-9e47-4183-89f8-deb38caee20e', 'd88077f7-b816-489c-84bc-c0b48e63b129', 'e9632448-5b4a-40ad-b710-4af752d91da7', 'd7540d89-cc3a-4a09-ba87-8486904803dc', 'faaf27d1-9487-41ab-9590-eeed78b69096', '81dc5696-d91f-4c43-9639-cb93e165ecc9', '17d94219-e3c7-4b32-a833-d0add6657009', 'd0e370ee-440c-4e9d-91dd-839cb62423e5', '49da405b-14ac-4a06-a0a5-baf736ef1231', '6c6f1393-2276-46e8-bf95-bb6b4e3eb1dc', 'e39ef207-6f90-4a3d-af8c-6498974f7b27', 'fa29f7b3-430d-41d2-9007-b046e71ffdd2', 'dd3bc87d-6894-46b4-88ed-6c3bf4c65764', '2a40a607-d5fb-4dcc-b9d3-707628380f8e', '3e0c0a39-dfab-4bfd-8848-b138e5b07b00', '9d92948f-4794-4474-9457-0c44047a66d7', '9b464fcd-d8b6-4533-9be4-5909e0103574', 'ae07e4f2-dee4-40ed-9f0d-4b5dddf6ae43', '352d9fac-a43d-419c-91ee-612a6eb57ff3', '0aa2a755-eebe-4199-be5a-56db83df31ab', 'a5885e64-9651-4962-8bdb-bf3ef0ed3c66', 'cbcb48d0-bfb5-4be4-a66e-42c54269680a', '17485549-7f69-4683-83a4-f919c47417b8', '43cc9227-a418-4284-a7b2-ec9effc83db7', '8ae5c806-2493-424c-b570-61720f3b7bde', '4736166b-a051-4cea-9d40-e20018510321', '371a325a-0fcf-4991-9392-4264eea7c188', 'a2f59adf-9188-40f5-a129-e9c6d8a3a4ce', 'db095488-1dc3-49b4-93b2-eeb2a3f9234b', '4381ff67-2958-424f-83ea-d84501805dd7', 'c39f2326-ed29-4198-8c1e-02fd34a561b2', '8e3cd3b0-d17a-4160-908c-e1a0ddc0d5d8', '6ed7952b-ed4b-4dba-8834-2350aba51dab', '6e3866a5-5d57-4e8e-955f-acf678a9cb2e', '0a86437f-cbcb-4776-b533-3737ebd27afd', '3fdadf96-e6f6-4f38-bd90-25f17e49fb59', '20d5f6fa-5b88-4fbc-9227-a649013970e5', '77e473fb-860b-41de-b703-02d172fbf608', '0f370829-7b44-4837-9793-6d3bb92d84a2', '686962c8-196f-48dc-97d9-0cf989d414c1', 'd6419302-3937-4dc3-a372-569041ff0009', '702ad1fb-c955-45b3-a196-24d3d2a7c33c', 'b12c62eb-f08c-4150-8952-bae1747183c6', '76603460-e758-418b-9ea4-d689cb2d3de7', '29a3a5ee-4bb8-42bf-9f9d-85a0bb247048', 'f04f370f-67dc-4d77-a719-8c6438083c1e', 'eb4a5d87-97f1-4077-ac61-fc84b99d42fd', '88b0f478-ecfd-4798-97a8-cbb2ab9e37d7', '8b7489e2-a707-422a-8833-95fdd26cb24b', 'c837b904-b572-4c6e-ac36-d13b8fc3a396', 'f854c8fe-d483-4ab8-ad76-c15c85137644', '3fab6eae-a588-43f1-99f8-c22979220851', '24314731-1089-4335-9176-da179392987e', '3d4c74ec-3297-4b92-9f40-b7093e9a0ed5', '76489c66-9017-450d-9855-16042062649e', 'cfe30d97-a72d-4d66-9ebc-52e66922f4db', 'b7051832-f75f-4223-9372-69bd93f9614c', '336a556d-f2f3-4df5-aa5e-646833ed68c0', '4a3fcddb-37ed-4e71-b4a2-0a253d8a995f', 'e05cbea1-0b90-4f6c-91c1-78063206cf84', 'ccea4c6d-429a-46b2-92e9-7ae18d0823ab', '9d496f17-6199-45c0-8b54-3d260163ed26', '5ef4f500-0c0d-4148-bada-d2744047d507', '014457d1-e5f3-4e8e-9597-9c65f172cc7d', '75c1b877-58f5-4bc3-b6f7-18eb313bd1c9', '112a25ab-2e9b-4c72-820b-8b347c6df8c1', '32ad7edf-a766-42dd-ab2e-18b9b1084d95', '2a5410ea-01b7-4f5b-8da4-ad7f9593e223', '8c748c1d-42d3-4a07-bf20-6fcc6dbb99eb', '2ddad24a-2d88-424f-92f3-96c5dda308d2', 'ac511777-9e1d-425e-96ad-4470f61dba88', '8ec4c369-ec28-40aa-a2d4-cfc6f5369d8c', '74e98e2d-fe2d-4b44-a9ff-e893c5821b95', 'fd47ea86-2d00-4778-9bf9-728674d518bc', '6a58f13e-1d93-4ed4-bdd6-580c0e3665ff', '202ec0e9-7c6a-4143-9bb7-9a87898041f2', 'edc80b8d-346f-42e9-99a3-5a797bf7a22c', '9228edb3-180d-4f6d-85bb-3d4fc0b103ba', 'bc9b1170-63c1-4283-806b-788b8ea00590', 'b0b13d83-c4c9-4129-ab00-ef1e8f595820', '4ac8130a-fa15-48b9-b798-9bc95f8d1a34', '07a63cbd-8720-41e9-8943-9255863ec16a', 'a6138796-9435-4012-91e6-c17d9bb1c6e1', '8d2a8a20-51b9-43ca-b8c9-21c290099a0a', '00e41c50-6524-48eb-af78-fc899832c6db', '75573994-627a-426a-89c3-cb8ed91319da', '43621263-795d-4da2-8dbc-e9cca61be985', '36731f21-9b72-46e8-b5a6-4d754deffac7', '02fab1e4-ba15-40a4-bc3d-ea6b952241cf', 'fe57ebf4-2e7b-44ac-b9a4-65b3e3fc369a', '01d32dbf-6a2c-452b-9de2-f763163c3d06', 'cbdaa5e7-7997-4ad5-b3f3-7c065a35729a', '69ace298-82c4-4791-a13c-f127041ce281', '9f7af436-05ca-4c49-9b3b-e1d4e086f5c4', '73528408-868b-4d81-9b75-49cd0d7e1347', '1501fdc5-5bfb-449f-9676-ea35083fecc5', '13d87e45-1453-4686-9856-ee3b283ae81b', '342dc546-f9dd-48cd-86d7-61aa61480fa8', '76466b27-ca31-467c-a1e0-b7f3346cc207', '7b730102-686a-44d2-85e3-8b765a1c85c3', 'b4a1405a-b174-486c-87e1-608599fd221e', '2d5f1731-eba6-46df-b07f-9b215c3f2fa9', '745fd05a-c4d4-4a83-ad9c-29af4a258d34', 'f1aa50b5-bda0-4bd6-b54e-ea9a422dbd85', 'db52d651-f5e2-45f8-b307-e4f75b17a6fc', '45078900-6aee-4a6e-91e7-862faf82200b', '6d2af23e-f133-40d4-b6fe-d7a769376029', '0d6e0950-8c1a-4c43-abf0-672cd00b64e6', '22dafe6c-7cbc-4b87-81b1-1c98dd1232dd', 'aa35d18f-06c4-49c6-98f1-b6a58b1d8c9d', 'fc085f41-2219-48f1-b7b8-bec1df88e6d4', '5107dff2-8d51-4139-955c-cfd2a75c840e', '63fd2998-19d8-4521-98c2-b4da01789fc0', 'aa38f611-8a15-4d95-b457-0ef1595a35ea', '1b099ccc-9ef8-4c06-8e3d-a35d06496413', '45aea59b-11d9-48d7-9994-fde93426d43f', '793f924f-8146-4c5d-88f2-8e2ea3329e66', '937ead71-3bc6-4ddb-8827-5479eab3bf9b', 'b63972ad-5233-43b3-b9a1-d01369977567', 'b4b8491a-9fb6-4fef-a5cc-b4384ef3d8cc', 'd6fa2313-ce6e-420b-ad20-5c8f7aefe82b', 'bdf5bb24-6413-42fa-9af4-4c8f661d491f', '70639513-9546-4942-9816-7eefedbee08c', '5473b5e4-48f7-4963-b5fd-b545a2ce23e4', '0af1db43-22d2-42f5-a9aa-10fc4c67d8df', '97a36e5c-ab0b-4e32-a3c8-ff5392381c73', 'b74ebfb3-bac1-4810-8d57-cf7c0637fbb9', 'ea0d0cc0-54c5-481e-b7be-1a8223f112cf', 'e21cffad-7c50-4c94-acae-d6749831e053', '1e01f651-6ca1-4b7d-ab82-e66a2b77b493', 'f74e0cbd-22d3-4ecc-b1d2-aa9d6eb78366', '6c21c86a-b3ee-47fc-b00a-bd5fabc8e60b', 'c5ca9a9b-df98-4a64-9d03-7d3c3eb8ac88', '31e27058-6d03-4855-8c8b-2dd65e22915f', '05ce0e13-3c15-45ce-b515-e03348a24db3', '2d0bf5c0-17e3-41e0-a341-7bf4df055b44', 'c5e179fb-0998-4e23-8517-d80c2b290d45', '821c51fa-c9d9-4bdc-a29d-2e4e2ad1edf9', 'cb834073-0691-4478-a931-3290ef9f5ce8', 'd4dd7edf-b558-4e09-a974-67727a7db312', '9fbc6c91-d6e1-49b3-8d10-b246860c63ab', '3a28ac45-8336-43e2-a67c-512193679d5f', '31e1ebe7-59ca-4fec-957c-29fd81492f35', '3264b95d-e655-45a2-ba28-9a8fc9242673', '3c077af2-2800-4d2a-82ee-3290872d0934', '0a031170-5c3f-46ad-bc4d-aa50975eccc1', '53888542-87ae-47d2-a631-df758ffa8ce0', '0fb9261b-3cc8-4ae6-9e22-0e7469edad20', 'a084a345-8ec3-47e9-83b6-1a5a253a1e92', '6e9542c8-239a-4351-b480-05ec9ea3bf2c', '186bf3a8-8f18-46a2-9f8f-b7ccc55be8f1', 'b5ea5cad-953f-4b0e-b850-f94ce2fe6591', '5df634e5-bd60-4be2-b498-f640ef04e4c5', '9a1dec31-e107-4887-af60-ae63118866cd', 'b741b788-7332-476f-82e0-752f2b6a1450', '66542c12-3d88-4281-a134-3f7d61bf18df', '44ffef61-a1d2-4a86-8c8e-e9fd39495145', 'a4b2d9f8-6ba2-4054-9bb1-3eb59f4a097e', '456a6325-28a9-40fd-b8e6-a9fc1582bcee', 'f49e0483-77e9-477d-9956-60ee1085f3a5', 'f071b35e-0019-4c3e-91f5-ba42fd2b7ce7', '50f6f5d4-2c34-41dd-b3eb-e8f39228d5c1', 'ba132ca1-c305-4294-ab63-89ef43f8a8e1', '581274a9-c872-4ad5-ac78-7d85e10ff788', 'e72ae523-43bd-440d-9995-4ce4e817183e', '97bcfd28-bf2c-48b8-b6aa-63e11e2afe19', '92725d1a-3bdc-4ba8-9ab7-e98bf3b0b96f', '24af55ae-9ec8-4196-a4c2-6e32b945f547', '7a0261be-c497-4f6c-90df-f27aac8dbd96', '55ec968c-995b-4c3b-ab61-90b042d35f2b', '45c0cbec-1736-4287-a1df-b9dd20ff3b5f', 'c2277ba4-245f-4735-b734-f3f12301f8c7', '4e0ab0f2-ef03-466f-a97a-1ecd2353bef5', 'a69a6ded-38b7-49c0-a6e7-b66bc279b58d', 'c250ea39-fbe5-40cb-b9b0-a6d028a1ba2b', 'ee8038b2-4229-4fc5-9d4d-fd2e35ec55c5', 'b8b644dc-fd43-47fc-9b96-0580b038b0ba', 'd63a17f8-1b83-44c3-85d8-065fe9705942', '4896b3ba-537f-4822-ab3a-f44f0b498837', '58c35790-8126-43a3-81b0-cb0371393b8a', '0f52265b-62b7-4d8a-9250-3dc86fc4c735', '8489fba7-9a49-408b-9937-473323b9ea1c', '49b24169-1a92-4e82-b7cb-1fae6cbf218c', '6ac66df9-a7ba-4318-8789-9ce8c01df99a', '17a427d7-35f4-4385-85b0-a2bab1a13062', 'cc48e14e-af73-420c-bfb4-613f2ef89442', '49493efa-da47-4864-9b4f-0ac663779c8a', '743182df-f8ec-4ab2-b597-0c73e32dd3a6', '175fcc08-d548-491b-88e6-822004bfd2e3', 'b5bc58bf-ca8f-4c75-8848-ec2872468f04', 'c6f71298-05d4-43c3-bb26-bd4515ed27ce', '12c1b3d8-8104-4b5b-b0a5-e14d1e8e0ac8', '2f6bf0d8-59b8-4419-b904-5eb9939df293', '9fe57991-c3a1-4330-a496-407c57334db0', '830cf0d3-7051-4efd-b4aa-9adea45b1cc5', '2b8c4976-b161-4f0b-b115-44673d735d3d', '6feee33f-7fe0-4e80-9890-0fb1f5873aa1', '30f57b11-5ee7-484a-b26f-95ea2d3788e8', 'ebd19396-5e65-496b-ae75-57e55db5c4c7', '2efdfcf2-a0b2-4ae9-92d2-79c6c1d0503f', 'a3428917-5cc1-46d3-811f-a745fb5d505e', '3b07042e-d308-4fd9-98d3-25b654e14790', 'e76618df-5efd-472f-ab88-bec42f5114c0', '99fa560f-69d5-45f2-ab8d-4bfb49e115f5', '267dd55b-ec6a-4c0a-81b7-e23e55545933', 'b2ee8ced-6ee8-4745-8829-d8173196010e', 'a01907cd-298f-44a9-b5fd-ed85f25f4c66', '690252f0-8c1c-4b9c-b532-e6ed0b92ebd2', '307d43fa-90ba-4c26-81a1-d5f4ab691cad', '219dcfee-41eb-4491-bef7-bdfe9c89cb2c', '54f8e456-86fb-4d53-856c-c1edb70e31a1', 'bd46e6e6-9fc0-451c-af5d-17e1bc5c2dcd', '76e42598-7b14-424c-ab8d-4ecc38444950', '8c545f5c-7fc4-4fad-8997-2fcca1414473', '28da3c82-9a52-4031-abb2-bbe73041cd40', '71e87f2d-4e00-4ac4-a1b0-503d6937807e', 'eb295d98-52a5-4f70-ae12-5509aae75834', '68419ded-c23a-4fde-8729-40f98d2fc32f', 'b70dc830-ab69-4508-8a06-11fec65a29a7', '36620d10-b79b-41c8-b10a-49cc7e3af0cf', '2b3c467d-65a9-411c-aa25-39d8f3265e2b', 'a16d70b7-05d0-4748-93e9-ef921d32cbbb', 'e28c4676-f4fb-4431-98f6-2e856f3e7927', 'b6789d07-9692-4cd4-9e36-f2cf667314b2', '476850f4-8120-490a-8e80-b8506881bfd9', 'a6752b53-48fe-4e60-995c-a8644a5f4ea5', '0753d573-c0b1-4373-9925-320baf151e39', '5bf0483d-d90c-49a1-af4d-a0a69c93deb0', 'b14a6090-d6b7-4179-b6ab-4e35393f3e61', 'bc271c3f-d986-4dda-96ec-8d8f9861311b', '36ea746e-62f4-40fe-9833-d6d8e4763078', 'faa9cc18-1983-4687-bc19-ef2a26f6a29a', '6581cdc0-7caa-43d6-a26a-143d168e2b73', '05bd13a8-f7d6-480b-94bf-ab1112492c44', '42150db9-ccaa-4270-acce-e191954ab76a', '451d7be5-3f90-4c21-9129-e6f6983680c7', '1958f3cb-0c68-4e13-8f79-404b59d52db9', '73c7f323-884d-41a4-a86c-0425130192fe', '033d536a-0294-4ec9-afce-184daf37cff2', 'ccfd07fb-eda5-4cac-b7d6-9558c31fa60d', '888e5992-4755-4a77-9b54-c4d9bf803b6e', 'fb422e41-337c-4d1b-b9f6-5ce88ab29b5e', 'a9428705-6b27-4fae-88ae-891ff7d88fad', '9a39f4e2-40d7-47b0-b472-b9b9c3b045cc', 'c7a04628-c7a6-4440-b15b-578c627f06a3', '002e94ac-8dd3-47ee-b2d9-85a87de0c8b6', 'bd154f59-b3a7-4656-8f70-3368b3e1c028', '9c9a5522-2dd2-4068-b193-414e148db3e3', '485b9c68-7918-4b4d-901e-0896d5cfd6af', 'a50de764-16a3-4072-acdc-f4de6c760354', 'b0f0c8de-654a-48f7-a27f-bbe14deb1c91', 'a0521770-05da-4f8f-aa04-ab6f846f822a', 'c80ccf88-81ab-47e7-b300-675a9ae7c6ff', 'aa6f0d7a-c912-4144-8f9c-d548ccf8f433', 'b352073e-0f99-4ab8-a30a-94918362906b', 'b2a19540-d2db-48aa-87a1-f54c3285799c', '050c6c10-445d-4988-ad8e-75e79a382c54', 'e16e8ca1-f5f6-42a8-b4e0-9c3009776036', 'cad18d20-45ea-4728-bde9-e92ebd7a64ba', '848c1fc9-dc6a-453c-a842-852c09af7628', 'cd774cf2-e236-48ed-b8b2-e395764b50a5', 'f8f468f4-5f93-4984-b423-de7b07d39c74', '832c5060-7cb0-4a84-a2ff-c2ac5a070250', '377111d5-9ebe-4d26-9440-93c7b8c9a1bd', '1aa47a50-cbfb-4208-b9c6-7df3da612a69', 'dde49ff4-1f37-4833-9014-748f63898d90', '693f4ed7-1c48-45b3-a4be-441ccc0f2d3b', '9dcbb334-5428-4447-bb01-c8252770dbd6', '1e2605e7-dc96-42d4-ab02-cbc278180e7c', '11f8a854-94f7-4868-89ae-17537019bef7', '0ded788a-e0ad-46ef-b295-e8cc5b829bb6', '13a02a74-1a45-475d-8ac6-16c08d354174', 'ad058e7e-0279-4c81-b6d6-91e3a4581dad', '8f17a138-164b-46c9-9621-b04e463b4042', 'd4387b24-fb3b-4439-ad91-8aec9bab6175', '602561b2-7b97-40b2-bf2d-3751fd083143', '7372ae7b-9f70-43b7-824f-683287e65f27', '75592a5d-a352-451b-a94e-5c6952dff851', '8f778243-4070-4eb4-b1e7-e29166bd3d09', '3fd92a0e-8f94-49d0-b1ba-8b1c102955dd', '5e3b55f1-7f07-4d78-b299-baee9026deeb', '4ce5baae-8662-4977-96d4-64a4e6063d53', 'cefb8b05-5827-47d3-8c1c-4960e79007be', 'd47a7667-f345-4dc0-87af-05f99fa89c67', '266fcd49-9bd7-4c10-b0ec-d73023214acd', '3aabc028-a44b-46ab-a2dc-cb02cbc32233', '5fc105a0-f8e9-4967-b6bd-aaf386b45a8e', '60cf3977-1a6e-4f45-8914-88625c330ead', '3a975540-6f8a-45d1-ad8f-ada2c7cd0c01', '985bdbbd-fceb-4ef3-bc19-2cb6623de175', '8c1de825-46e6-4292-b0a2-9843852567be', '5381e709-f72c-4172-bb07-e24cb2538e59', '583fc78b-f3eb-4b70-8966-6bc4c0f1b726', 'bcde76ae-20c1-41b0-b86c-26eb3fc29aaf', '40954333-7e58-4652-851b-3a76fda3ec9b', '85881fcd-d482-4b16-aab1-ae832b9c6fa9', 'e62d6515-becc-4f30-939e-a241104e748b', '138423f9-1970-4eaa-99d3-5220ce92477b', '63a5c228-c63c-427a-93ef-6b8a3f3390ad', 'e28d741b-6549-4504-a459-cdb4110d1f9f', '7992a881-0d00-4b5d-bd09-db16b27f8d62', '44a53ee9-2317-4b9e-ba78-1e4638eb86b9', '623b0030-257e-4aea-b211-25627e22aaff', 'c79e554a-2c11-4e30-bb84-c1fc60c88c1c', 'a6b7ede7-5e9f-4a0a-9746-8a66b2042c93', '7c485d42-0e65-44dd-8413-f0f201869183', 'b41d94a1-a894-4b0b-ab1e-959351dd135d', 'b85240ff-2f68-4ad6-94fb-1bf48989a455', 'da81f453-f520-418a-ab4a-ec4a0b24c1a5', 'a759cefa-9278-48d5-8098-ae901505832e', '515fa374-01cf-46fe-9362-f04e89fbeecf', 'd2336211-ebc1-4c3f-9697-03bba27e7813', '91f48b90-9e24-4b2a-8a67-cdc2033c72a9', '6c074f09-7744-4e20-9afa-4adf6b76cee2', '48741231-789c-48a4-921e-ad553f2346f9', '83bb5db2-9c05-4b13-bb18-204c1aa9b8ff', 'b77f317b-b3cd-400d-9af9-3e1d6620dbf5', '129badd1-9f63-4517-b741-c1c2dceeb09b', '538784dd-3e20-4c5c-9001-eb031f8b5bf4', '3d3747a9-3b48-4968-a837-7adcbf4f0b5d', 'b9e3e679-3b9a-4365-a83f-0ede74a8ab1a', '2155cbc9-d53d-4e23-bfbd-967dc0bf7d4e', '84f64d6a-3c59-490f-b252-93fe04055404', 'ad02a327-e981-42e6-a3c9-cdb8cebe20c9', '945053cb-a902-4082-8c2b-0dd4f6ed95e5', 'e7eacbdf-792d-4e5d-959d-fc3a4b271eaf', '048690fa-fbeb-4662-9a9f-1f29288e8309', '38df57c9-b998-4ff5-9aad-7ba7279d9d2a', '63087566-4e4f-42a1-a6ea-a8a5f3e04d54', '7e3b31fb-b8df-4785-9159-b7ef0dc375f9', '68cfe0f4-1119-443f-a408-097cb58b5b41', '767d7022-5268-45d6-8bb6-faf30f77fd40', 'a0361d80-38d1-42f4-94e4-73917ef4c474', '651a070d-50f2-4419-a6b4-680cf66cbde4', 'ae820b00-c83c-4cdc-8a8b-a9c9b3e64b02', '3351afb1-eb6e-45a3-8dca-31660d133ee0', 'cc363813-e1b4-4f47-90f5-c3e38cd8af2a', 'ecd2ca65-01bf-4e50-bcfe-24a970d2df2a', 'c1e2ca7b-30a3-4e36-8fa8-5ce66d618d45', '151d6a5c-77a3-4c6c-9d23-e0fcaecd81ad', '166129d4-2761-43e9-987f-fec11dc7e94d', '2600532a-c80b-4af8-94c7-85e28de70a58', 'd2337eb1-8b26-4e8b-8d9d-5771b6e75cc1', '95782ccf-de40-4f3e-b0a0-0f534421e4b3', 'd048bda2-ad2c-4160-a019-cd1a599d9d95', 'aceacd27-28b9-4e37-bbb1-2b166e6264e4', '60d0e249-8fdf-41ae-8eb6-7f15c8c64634', '30f0d66a-a29f-4b7c-a288-915cc486a7ef', '93309c4f-bca9-4031-9d52-39cc2bde0ddc', '9d6452a1-65c5-44d5-8df5-cdc4f707d39c', '585406de-06f4-4faa-baff-d3712b1c8ba2', '95d2862a-dd00-43c7-b55d-917bc36a3a7b', 'a2f09bda-2594-4a86-9ba5-159a5e7d661c', '7ebe602c-c079-4755-ad7a-560ccc6cf077', 'cae5a5d1-0a83-4e9c-bb30-9517e27bd06d', '6cd760ab-74b3-4050-9a36-e027617ea181', '2e17f0c5-4d8b-4088-ad58-1edbe07a5cbd', '6536aa32-266a-4fef-98de-2d56f3404b12', 'e355c281-334a-4901-a94f-c53bd902c7e5', '47846074-4d90-459f-b367-118335111f33', '1089294c-7c09-4776-8d25-98604cb7f99f', 'f120c403-04a8-41e5-aef1-c6f32ae65319', '27d001ed-5245-4df3-9aaa-d2e6b797a349', 'e1bbf5c3-d53b-4974-a8f9-41a37b67b16c', '1daff73c-59e9-4c75-a340-bb939074fdae', 'e1fccbd9-135a-407b-b116-e4ee049bddd4', 'cf1f686f-6051-43ae-a48b-d4352d318763', '172bfd54-0523-4fa7-8af8-be360d51471c', '346c3857-21b4-421b-89af-6fa506e5e0ea', 'b8204fb6-c996-4183-b94b-e44cebe48693', 'ff587d4c-0159-472c-b5e1-8e38755cbc49', '06db055f-edb1-4eb3-8aca-1a775acfe767', 'fdf090a7-3674-4433-95ee-75a20e45d39d', 'b9e19f55-b9c6-443f-9163-dd951b6ca1df', '5c59ce74-ecd8-4649-81ac-9fd267454b68', '381a5d76-6ab5-4213-97c7-d64f93ceaf15', '8987e15a-4e63-41cf-aa2e-e42c2f9749f6', '10450e10-cfab-41a3-9022-d84c6389aaae', '2a19a070-fcac-4889-8229-d817d598740a', '54ff0ba1-2d1e-463d-9273-f930416a0c3f', '983bcfdb-c56a-427a-9325-2390bc2c0ca2', 'b9fdb3ef-877f-4a65-9190-e93f043ff518', '81d376aa-ee94-4e67-af3b-03cda9495bb7', '49a3e18e-cdd0-443f-ad77-8430af59e36c', 'c867f20f-fa59-403e-9643-472c5ca8b60a', '8ef3a1f5-4474-453b-b572-761073c22ceb', 'b531b2d4-3a12-4b0e-bd87-773075d6eecd', '42e62754-fed3-40b9-9733-a7b5295c835c', '22607d7c-da9a-4ab0-aacd-eef1093cca33', 'd8d44671-600a-412f-a046-0692bf3bb754', 'd7fea894-48ef-431c-9953-647c9c901c77', '37b1ed38-9f84-486e-b133-0fa82f06f1b1', 'd77f0aaf-4e87-4c48-827e-3b701fc72ffa', '10a6f887-2548-4db0-9457-94488f046866', 'e10e2d96-2b6b-439a-8824-883fc4d7f07d', '066d33a1-69b5-419f-a03e-849539274dea', '6282f19d-4f9d-4350-97a6-76fb17b06d12', '473f6b34-ac67-4868-897a-46c96c5910e6', '0109ca51-f089-4a15-9134-c9ee3c6fccb0', '4515db8f-ccc5-4cee-9db1-12620ff0af64', '32092b20-615c-4ff4-a334-f1424b370484', '89bd66f9-7b1b-4c2b-87b9-ae51950288ad', '979345bf-2caf-4f05-900f-1aea9a32f589', 'ec763edf-764f-4734-9680-d82cf23fe77d', 'f03de55f-763d-4ddc-95f0-5368abb16a40', 'd9ddf55f-2cf2-445c-b4fc-8f71fd21babb', 'bf9cbf93-901c-49fc-ada6-56c30b256254', '3fb64f39-7c76-4cbe-a96d-40ef5fe2ae44', '4022490c-2fd5-45fd-9966-88436fc75154', '0654647a-1145-48b4-99b3-43f2aaaa3663', 'e555ee6f-8a63-480a-9715-4be58a6e2a60', '7303fa25-d577-4d23-9cea-3836ba57c214', '6a5451f1-ff3c-4e23-94c9-dbc24c56c13d', 'b2877749-4429-4a9b-ba17-fb1c07c7a81e', 'e0f56879-3aec-4447-85c8-60b4d7071da6', 'aec11f3a-a240-4b27-82ff-97317fe3a1db', 'ee4b1cb5-6f26-4b42-b6a2-45296a19f54d', '02e07efe-cd78-4213-9243-761cf5ba6c2f', 'a8312747-1d43-4681-81a7-e4fe472ed4b6', '3788e24a-c2fd-4e6e-92c1-a2b5b6c43e4b', '48d96c5d-49fc-4d86-a1f7-e654ad04d565', '17cb6977-8fb5-4685-afd5-358832140330', 'ccfa2350-d6e3-4180-b90d-1a3fbf9a3cac', 'c59bbfa6-d830-4b8d-acac-22a87ca7c4f0', 'ab3fe30e-2b74-4940-9241-93dc09af52af', 'bef9c483-104b-47bf-803b-f31d1f1af354', 'eda3962a-546c-48e4-990c-2d5fc20e5123', '08d36114-a7e1-4751-972b-cbf21e219f45', 'a3518c33-4d7c-44c1-86ae-d52ef867fb73', '6d653ed3-0b6a-43b6-a572-430bccad6f33', 'e6b03d04-2637-4ccb-a3ed-bf662bb19bc1', '8f7d8034-2e66-4a40-a54b-ca31dde56056', '8b4a626a-806c-4a83-be61-69c97e1c1393', 'c46b0d59-e90d-44c9-9903-fe9f87aed744', 'd63ed5d7-f6cb-4462-bb53-8e66c3651747', '0ff5312d-a7ca-4f24-8f6e-53f9616f671d', 'e6fc832d-4ce5-4bf1-86d0-b38a7bffb5ef', 'e78b4a01-fd80-4d25-bcce-7bad07f19eb1', '2d41e2a7-61bb-4105-89fd-7c8382888522', '7ef06d9a-f284-436a-bea7-89948e5cad98', '8f12ec18-19a4-457e-8501-b2f20662d33b', '14e171b7-aef3-4ffc-b213-08e0a1d521de', 'a19df401-f6f4-4603-91a2-46ec3acfc397', 'fabc50c0-9868-4a66-b251-e5daa74bf2f4', '7f649301-e1dd-4379-a2cc-86e97969871e', '497a159e-798f-4897-a421-fd0ff83624f8', '3d95e188-cb29-4627-96c2-733f767585fc', 'd9733616-46f6-45eb-b39c-9c79072b8c42', '6e31c912-45a0-4b75-8550-4b0ea554d2d6', '3ae11d33-626e-48df-9169-076ab38af02d', '9853c30c-3d8b-4158-b7a1-50d6bab88879', '095250c8-b591-47e2-8234-c5dec0158d31', '9dd85dc8-fde4-4efa-a334-1eb050255fd3', 'e2f989bc-d93c-46a5-99b2-e2d8377873b8', '86e7700d-7a93-427d-8b0e-08a4b6750807', 'd7c2eee2-d760-4e7d-9474-c5302a9bf3eb', 'c13dc1af-6e0e-4fbb-b801-c1ef3a1306cd', 'ee568136-4e11-4565-aca0-271f4511b782', 'a5c9dfb8-b4bd-4f23-b5b8-096c05e16f8d', '6cac7534-cd93-4622-9607-7bffd00a1d75', 'c61e929c-03b0-43e1-98ac-d99301225c74', '558f2935-2648-456d-a780-30e6dc4f22d4', 'b59e2fa7-fec2-4efc-97fa-91871b8bde55', 'fdd5b421-ac22-4b1e-8cf3-634e7150b783', '4383ed63-a479-4a90-8a18-54a22c520d1e', 'd0e9a82d-b422-4ced-92c4-9eb2b093fc8d', '07f8dd87-8b75-4d18-8deb-5b0a95573139', '4262040a-b4ec-436e-80c0-29272bdcbfdc', 'faee31cc-b531-4e4c-a57e-577abee69f82', '0dff95fd-20d8-4994-8992-05352b9578e0', '0be4efa0-882e-4cff-861f-47f1b0a34c78', '0797019c-7a6b-45e7-b2ee-9a987d9ab9b5', '50615ee6-9ce5-45f1-b95c-fb90015d301e', '3d1c445d-f1d9-43bd-b11a-0cf8247843d3', 'a6396b81-821a-4a13-9b0e-047a3f9cb9fe', '3b4c224e-b1f4-43a0-88b7-10c2c74cd33d', 'd70cf582-4fea-4137-84ca-3a8ee7a9a181', '0cfd7a51-1ec4-48ac-a2ac-de610fb72995', 'ecf4be03-b5fd-46d6-bd8c-8610098e31ee', 'bc07a6ae-900e-4a2e-8cd4-a49a1c5e4157', '73661ae8-b1ba-405d-a66d-1309b15f543b', 'bb970e69-a1d2-478b-acad-9a01f4e635d7', 'a184561f-0dc4-4b7a-b342-c96560d10851', 'df2f4e4f-7fb4-4a4a-87a6-516a47fe47db', 'f5477902-cf93-4b70-99df-d3d703337e98', '34ffce8a-e37c-4b1b-93ee-fb50a5b4c770', '350088ed-2f81-4f1e-9e24-6d0ceda1bdac', '2fc7fb24-551a-4716-85de-14982d10e22e', 'c05a8c40-f00a-48af-b7f0-840948d4a90e', '1f31f9d4-ca88-4833-9669-8452a43c3163', 'fdc3eb1d-ccf7-4da3-935f-7e531eb46205', '530e36ee-c616-4e68-80c2-4d7d9da939ed', '2a769e84-85d9-4120-a956-1bb34db8fc6f', 'a4e0818a-cabe-429a-96ce-1d9e3f869ecd', 'bc117dd5-4fc1-404c-bd9d-8c00c3f244a0', 'd2dddb33-e146-4915-ac66-d64d69833110', 'c6204c89-34a6-441a-ba80-954af4159f09', 'bc0ec4f6-f6ff-4885-a238-989d32e06111', 'b06689d6-4386-4206-b9d7-02ddc2b3d74f', '4d918065-9505-4f87-bdcf-bafc04c5066d', 'b2fe017f-8846-4dc5-9d3a-1d0ca6bbdfa4', '0585d981-80f5-4679-9451-30d43bfde943', '5376cea2-d527-47e8-9b3e-cd49c0aed668', '925ba55a-7c12-40bc-b950-41d843c47a8e', 'c5425d35-9468-4431-bfda-415dfceefab2', '0e61348a-9546-4f0c-84fb-f867e1311f3d', 'febeb5b1-88c9-49a4-9bb4-603391448c0e', 'fa09447f-6c53-4f26-b089-13dd59e548ab', 'd7d00d5e-4c83-40d3-9be0-3e2abac4034f', 'c773d85a-2260-4e4c-9619-0079046ae195', '5e8ff285-54e5-4cfb-8540-cfc446eef828', '8b84de4f-b171-4462-b776-8bb0f71d7689', 'a3678af0-8904-4c12-ba49-642370c96075', '2836d0f7-79f3-44c4-b566-36f30603a618', '99279495-e190-4287-a2de-fee427f4e06b', '5ba2c3ee-84dd-479d-8ea4-c16f1ece165c', 'a8111957-5471-489c-a4a8-6279d19bafb1', '8331694d-47cb-4327-8a64-9b71b6c8fa54', '10d92778-8b60-476f-9308-db752c95f97d', '94f8a481-e44f-473b-b5e4-c6ebf6222b2a', '7f749a1d-2f04-410e-a658-fdfdf66e9e04', 'ea842db2-36bf-4c95-b79d-71e3e03bbfd6', '2afd6263-78d2-4a4d-ac31-6accf528b65a', '5cc15ee9-505e-43a8-a00a-b90add085a00', '51e8732a-fed4-40b8-ba4e-ae8d2f83abef', '44d0b3cb-860f-42a4-a785-f43cb7478f31', 'e00f80b5-f372-4529-b19e-68cc788f96be', 'a9fd4cfd-cc26-4295-8e02-dcaa68a9cf04', 'c1b844bb-b97d-4665-871e-fca97937ec44', '18067654-be13-4c01-9da5-b7e2dbe3a8b5', 'b73da58a-8652-4ed6-8277-f795973d5b5e', 'f9514f94-568a-458e-be74-b7def6026c36', '276bac37-fa88-43e8-9ae4-32fb00b7008b', '069da02a-b5a1-4b26-9236-3b937cb16c61', 'f292adf0-bea1-40f1-b1f3-df27f88b8f41', 'f470779d-6cfc-4470-97ac-b26c2dc333f6', 'e8d2b890-80ea-4e29-9a9a-6dc2afe00c4c', 'f019d5c0-6013-4c49-9390-b7ec01164f25', '1889a133-6594-43b1-b250-1b1bd50ae957', '3d850aaa-4c0f-4385-bc87-ce183b9d3686', '686cd11c-6fdb-41d8-8fe6-a4cf8ec500e6', 'e2d8c047-ace9-4ecb-992d-daf8b79ee84f', '8a7fb13e-02a5-46b9-8fc0-77eaf6e978ca', 'aefa56d9-737d-4a7b-9bc7-d078bab2da90', '78aa1df8-594b-4253-9c8f-4d2481a95da3', '51676183-8430-4ea0-8c6e-dad506f7187b', '8cfa2924-a454-474d-90f0-309ce075927d', '074b5889-379f-42f6-8f68-1694ef951ca4', 'cd207efb-94b6-49a6-b8fb-712856077f41', '26582f9e-53c3-4f84-a4c1-4506384c1315', '6d8a89af-02c6-4519-aff3-8341eb885b63', 'f85b4ea0-b465-4b95-b758-f76849d2cacc', 'ce568dbc-6aae-4938-9ae0-9403f4ea49a3', 'ffa67893-984b-4c5b-a905-1462a15b0dd4', '9e9d4e4f-b420-40bf-890f-40580fa3fe48', 'c617a4b2-9e0b-498f-a6a4-d53f9905f842', '1d5ff3a8-ccc4-48a9-93bc-7528e722dd47', 'eb436bf0-b294-42c3-b67b-eef0f49ad4a0', 'd4e878e4-4862-4116-b468-379d989f728d', '9ac47f70-da7d-4cc2-b4bf-6e2c463b9c5e', 'b636869d-e8bd-4007-8f2f-7fab968e0ac7', 'bb39a77f-5126-449d-9100-74c3a7e6e2fa', 'f3621f14-1226-442d-a1cd-b4e3500f1b43', '09a9f5ed-d8ad-47dd-861d-81a117535b43', '72fd420a-b523-412d-96b2-e18b91942c39', 'fae4c5fc-f2d2-4984-99b6-c0d30a16dfd0', 'fbbd1e5e-b7fc-407d-acce-4eafaca97a54', 'd5c789bc-dbf8-4e5f-a89a-ae3cbca8cd39', '835cd44d-a022-4a70-8468-5f1b4a9be213', '8f4e55de-f716-48c2-8528-7b1ac41ffa94', 'd26ad198-c94a-4033-82e2-63391758fb7c', 'efca046a-29c3-4676-9648-92c8143da52f', '28adc0bf-077f-4756-a273-eb5da03e9f55', 'b795469e-1639-4cba-9c23-9296075e8409', 'fda662d2-348f-4403-a6a7-c25542e365b8', '8fb67ebe-e4b8-437b-b244-5e957ac711cb', '4dce08ec-42a7-4173-8447-db1070b3bd3d', '9092c7ca-61d3-46f8-bd87-2bc69c76c400', 'd4bd4d3f-79c3-4de8-a737-a16b5b8b96eb', 'b3ac74ba-bb07-41c4-bb4c-1cf231c18003', '8fe1f454-03e4-48c2-8a01-0b715250618f', '94381e8b-c75d-41d7-b345-9e4e3e127336', '286e877a-7625-4ceb-ad74-42f13dbd6cf5', '3dc94002-f3d6-4ae3-97d7-8d1f3dd23b34', '0ceb58af-4016-402f-bd5a-cf343afd74ee', 'acc49d17-86dc-47b9-b0e3-b0f7a4a88f74', '8f0117d4-07d2-418f-bc35-c4ad8997ce82', 'babfa59b-238d-4624-8bff-852f3ccb35e0', '82fc917c-0350-456e-86ec-96b37cfb8d26', '3edf8308-b2a4-4137-b387-2aebf844f074', 'de79d975-22b2-4b83-8fd3-15b5ca62934b', '42c501be-f754-4b33-90ad-f7df92b536aa', '6ac7f8f4-23b2-4798-9697-283790ea0e53', '58de880f-0132-459b-9d34-2ec6cffc940f', '63027404-2bf6-47a2-abb0-46cc8b5adbc6', 'b2cb1d08-96c4-4268-97fe-242c80aef228', '3047be16-047c-41eb-a50b-f11cdda53432', 'e846c468-ccda-47f5-a11d-a89f81ceb404', '36d1d546-1437-4af3-9dcb-5588b100752d', '836b52f9-6544-42d8-8c85-05cd994b8d76', 'c858e944-a3b8-4066-85cf-e0bb26917fb0', 'ef53bd75-4c9c-41a5-be5f-a44e615f6322', 'c0add641-f0cb-47a0-b257-c676fce98ac0', 'a78c9c9f-629d-4e75-9e03-a8cd5852432d', '6bef5929-4664-42fa-a9e1-b7e46d002b6f', '2adaceed-ed2c-4c52-9986-9d3dd1e86f16', '17de2ccd-9ea7-4568-9131-881a2df7528e', 'ed689150-576c-40e0-87a3-e81a70e514f2', 'b4a87090-3da1-484a-856a-dc75deeacc4c', '85407b00-3265-4049-84db-ec7379175fb1', 'eed90740-0ab9-4aba-a525-aa880a3e331c', '3931242c-0c8e-4f4b-a8a3-70b7564b6c0d', 'db76e833-1b8b-46f9-bcbe-8674e9c17f89', '1b7a2d5f-2609-4f73-b27e-f9e5382f38f7', '07c3107d-2b77-49f4-9984-c3dba7b5a4f8', '2800c182-e89a-4f39-aea9-d491757413f8', '88358122-b0eb-45eb-b5ca-9fb3128c1e20', '7a0a9bff-6ba4-453a-9ac3-3a3396d68e24', '4ac9b30c-68b5-426f-b39f-1c31444a3b63', 'dc742c40-7681-4360-ab29-1a83e8140e2c', '23af3e7c-fb77-4414-b9e9-a6f4f3ed646c', '591a093a-f62e-48d8-b433-9b7c3b447436', '56ee0b49-5f8c-4dc4-89f8-aaca6cfa9ea8', '23d8b42f-3d7f-43c8-8d22-d01b669114c2', '2e602f35-c45a-4417-8380-646572e19800', '9afeb6ca-7828-44e5-a079-bd10295431b7', '203c8bb8-e498-4515-b0ca-b90a3613bfb1', '5b25d531-9dc5-4efb-8005-0c5bb4e3aac9', 'a810706d-fc01-4131-b2e7-fffbcfe3a19c', '80b6a3b8-d452-492a-a8d2-2946e7b18975', 'fac26f40-0437-46c5-ad97-cc705f784a97', '82a2ac58-a54a-4685-aa3d-05b9229d965b', '2c4959aa-9633-465e-be14-76fa2644ba27', '9f37a3c7-262b-42d4-8bf7-03697730cdbc', '73608ec5-fc4b-4782-a616-c99c7319f3e1', 'a23e8faf-3e49-44db-8934-5665ccc211ff', 'e770625a-a269-4674-9a56-63c23f2db001', '335d6af0-1468-4335-a0ae-a6389e576ac9', 'a4e0eb6b-dfd6-4729-91ce-2b7a5e37730b', '40945a5f-c2be-4894-acb5-ba8ce4859dba', 'c5cbf100-8ae5-4039-8d7c-6df80d135353', '3d6a3c85-db81-4e84-9ce4-248c382d1c7b', 'e9d6acbf-ea4b-42e4-a797-1120d05fe1c5', '41fb08f4-316d-47fc-878d-7554155a6552', '530fa972-c279-49a9-927e-3517252c3547', '55a91ba0-a64a-4125-ab13-735da011471f', 'c6aa62e6-1399-42c2-b3ed-071e25586f31', 'f559a8e5-a7b3-4862-9468-86baef1d7624', 'a543a3db-ba88-4da2-ad92-70c3c9b89d09', '8c204b9c-5e8a-40cc-90f1-91ded0b2247f', '98a8b272-dadd-48ce-a565-bb9fdf14a7f2', '69948841-1ff5-4c8e-b6a7-deb8418afaf4', 'bce190ed-59c5-4a3c-9721-71610e909547', 'b1e9ba16-de91-494a-b9c7-850af26aeadd', '8942ff3f-e0b0-49d9-bfa7-fd014e893af5', 'b9fbc968-53ee-4522-802e-fac358507297', '0210d436-afd9-44f8-b430-adbf3bfc8d2e', '9c326ffc-abfd-4d8e-b24c-93c306c815ec', '8a56e642-c70b-4675-a0b9-5a5ba8f2887d', 'eeb82df7-979c-46b8-9b0a-577d9a3ea2ae', '33f51df4-3ead-4f06-a8fe-24e80ef3c343', 'a5dee1c1-ab04-45c1-b272-879396cf184e', '11d65b50-3f64-4bdb-a4ce-5558a0e47267', '326d816b-13cd-4386-91eb-f40c9b31aed7', '8bbebbe2-34ed-4b5d-ac96-d0471933204c', '1a5cb195-0e58-4c0b-820c-be46b2ace441', '096fe0fc-afa4-4879-b90c-634da4e76503', '1e7add47-3058-4fa3-b3e5-5c359b7cd54e', '1e165c31-32c8-4ebe-849d-e9c62fb1df4c', 'fd42aa3f-6883-46d7-80c2-82bd0b23ea96', '04abae48-c431-45d2-8368-f9f747b11105', '544e0620-7665-49d3-b183-1c7d3625ee6f', '58fe0390-3eb8-423e-a218-1806af008e8d', '861a0bef-a066-4e5c-9a9c-2f9493ea1d72', 'ac97022d-63cd-42e4-86ee-b62fe557465f', 'b39e8e72-4ef3-4882-b740-4d1e05942bb8', 'cf004e6b-c920-4594-b6a6-1753b2c9aa46', 'ca90d60e-4a8a-4f02-a62e-aef55b3a41ef', 'af934289-bf78-4749-bbe1-f49debe5b051', 'a7614c22-b6cd-4f76-b69d-c85b90aa8217', '148838b7-d787-45e3-85f1-3ed2770882e4', '66aa0805-7367-45c0-b487-dd54def25a2b', '5188bdec-f73d-4862-a247-c85c9604d1fe', '7ad77c83-508b-4e87-9d2d-b841b7d06d36', '6ec8d98c-5a4e-4897-9c48-8a819b61732e', 'ae321247-f32c-406d-ba92-873ec9f68b65', '882480ba-f9fb-4f5f-b5d3-e43e33ade3a3', 'c67ac284-a801-47e9-bae6-c5fc10c345a9', '31020ccb-94ac-4bbc-83f6-1652e3be1126', '57ebb0c6-fab3-4e04-b435-4bde4b6e125b', 'fdc67c11-039c-48bd-8172-0a6b0c2c7ea1', '74c9e7a3-71e8-4cc8-b69d-d74045d6d77b', '6562bbbb-b81f-4e0b-aa44-9d52c38a33c2', '845071dc-2939-41d5-afa2-800b91ee3cc1', '2361a270-0dbe-4f81-934d-394d7664ad7a', 'a3302886-b0e3-4600-ae56-3bae56ef58bd', '3fd3d8c8-313a-4f81-bf15-3fd7b894e2ef', 'c22eae17-bbe9-4450-a327-3abc332eacc4', '472aa17d-ea9d-4ddb-ad7f-e2936e081f0a', '9c0826df-6a5b-46e3-806f-482e54d63b88', 'fb6d5d1d-9b0f-4c22-bb14-697130cf3c3c', '24fd1e32-7eb6-427d-8468-23bcbac7ff87', 'fd2e3732-a86a-4b3e-8ebe-f328d6127dea', 'ef4069e9-26d8-4634-aa67-bebf26ffd066', 'e7faa3ba-016d-4928-b5d0-e799ade17204', 'f12ba14c-1d81-495e-8c4f-5bde70b9251c', 'c6e018e7-c5e3-41a1-a4a1-bbb1c0ede558', '0175878d-80eb-4388-ba5b-205f525782cb', '850a56ab-ddde-403f-a050-07f4724f0790', '01d3ff89-88e5-495d-8e76-c7dc85c16dee', 'fb92b16d-6d82-481a-b8a0-ad02db4b5e9c', 'a22ab0cf-7c53-477c-a4c5-11feec49013e', '81b6f87f-61b0-4d97-8842-b1eeeaf0c13e', '50c61375-b3d6-42dc-9a3d-78f114e0a120', 'ab3ca7dc-ed1e-4839-96d5-e28f81c2ffd3', '9f4a44cf-8f1f-44e5-9e7f-8ec980bd8f3a', '4a735dc5-a019-4793-996e-5a8555f3b5e3', '69b43ed7-5f67-4497-bf73-6098ea4cb0ab', '642d7766-3c97-408c-83e5-93906d98ad8d', '78a591b8-7c54-470f-918c-f1a8e03f658f', 'cbc094d0-4a69-4084-8e8f-532906909ef1', '31faf06f-6ca9-4a22-b7df-2176ccd180ae', 'f2ed5653-142a-446c-9fc4-1c1635095612', '8025935b-21f8-4706-90ba-0ff083f75f34', 'be04aa91-448a-4391-a895-ed2318cb9c17', 'b85da905-c0e7-47fb-9313-e52c4b8c627e', '45502911-ad9a-4eb1-a258-bdfeb760d48f', 'c2f5072a-5ca3-449c-a163-fd0be02d7cf8', '91984627-025d-403c-ae32-ee07f1f5e27e', '19d8d9c2-e575-4f18-8f31-7c953f202688', '7223feba-cc49-43da-8bed-bbe82b8f329a', 'f4deaef0-1c7c-483b-8a75-239cc1c0fa55', '4a26b80f-db5e-4b92-bd4e-fd50999bb954', '5a30099b-2d09-4d98-ac37-14422e03ac11', '11090b37-65f1-4dbf-993e-bf57e8e3b7fa', '4618f66e-0378-46bd-9085-82c62f8a2f0d', '08b9b6a4-35ad-49a7-a15e-0d11bc87c563', 'b46900d9-e910-437f-982b-31bad9f1e57f', '5848941d-73d1-4645-a3ef-1050bcf81c39', '53e34df4-fc74-4263-8554-8585f2a51d9e', 'fb0e8441-f9ff-4627-8f3b-98e1a0e16753', '4c227dc3-4600-4a9a-a326-9862bfd27861', '98df1880-b72a-4be1-b46b-28248bc9bf30', '001358fe-6f84-40fa-9898-c37fdabe6092', '910c7b7a-55d0-4b3c-88a9-c77046253add', '2cc055f5-5027-4f3b-8be9-03163b236a6b', '965280be-9297-47b7-81f3-073bebd145c1', '9d4792b6-1844-4950-ace0-e75dbd7af1fb', '75a51460-bd2f-490e-9073-48e9862f3ebc', '53dc4395-0697-4d19-b968-f62d83732846', 'd5648115-62ef-44e0-a49a-8c91c16532c6', '1a61cfd7-fedd-439e-9f32-aa43df2e225f', '05f4bf95-2f87-4eef-a45b-04787acac9ee', '8271e0c9-90e9-4c08-8704-6654e4f26ebd', '43a439a6-fe9b-47e6-9b39-23193a60709c', '42f52bc5-0400-4910-b0e7-f495cee76356', '348056ed-17d4-4141-98d3-8cbbf9d0604c', '67e8aff3-f938-4d75-9b6a-de27b47d0e6c', '5eb366c5-c119-4b41-b341-2463aaef2086', '9de84ecd-0a5e-4cb0-b109-df01b6bf7ea4', '088905fe-4284-45ec-8088-d4fdd65f88e0', 'a0c66699-cb80-4886-afa9-1f97ee47cf99', 'ccd6a4e6-ea7b-410e-a193-24a80661cde4', 'b8b38357-1617-43bf-8604-a9155dab40d2', 'fce9089d-8ac9-4cd9-aea1-775d5784e6e9', '07c48c53-2d64-4582-9727-74876833922c', '0065e6d2-131b-4c4b-99ef-6c248ed5a6ad', '5cf47d46-da07-44d8-88fb-eac812fcf25c', 'fe536a1c-c59f-4a06-880b-2367cd5258ba', '22b1a679-007f-4134-b56c-c1e59a20c175', 'b13970f5-59b0-46d5-852e-ccec44a88658', 'c792a7c4-077f-480d-a8cc-f59c765c6656', 'd05f4bc6-25c3-426b-a15e-ccf99fa8e78f', '3b64d123-f9ab-4c21-b7c0-c1f51514ca82', '4e973a5b-29f6-413d-ae75-8af42e0c2173', '145e5fae-5df7-45b0-a507-73ae794ee572', '2c13f8e1-401e-4da9-b618-fe909bd30a5d', '837f346c-0d23-4cff-a81b-7a4a2c8dcd55', 'ed278863-0db0-49c5-b54b-6f9b086d7b2e', '708a14d3-9ca6-4a7d-b56f-3d699d4f4c6b', '5cab267d-3681-4ca6-9205-92fea6d8da34', 'f0a3a35f-1dce-4e5d-95fa-e82f7a98eb63', 'cadfe272-aa7c-47c1-a447-9a52439d6b6c', '7c0132ab-8251-4579-b1db-b28beececed5', '35596ed2-923b-434b-856e-36729c1d0cf0', '2b07436a-c7e3-4976-83d7-c270e5045a6a', 'bf5d9acc-a8ee-4cd0-8c18-89629e890cbf', 'aeadd257-c387-47f2-8634-c3eb1753de5c', 'f1f53f39-22f7-464f-b42a-bf7d4ca0a03a', 'f3ca9904-6814-4ff5-8c9c-be85f48aff8c', 'a079ab86-b2e5-4dfa-9f54-5e16867c42b4', '20d9ac84-af60-40a1-bd7f-28e84f5b46c7', 'f0bc8dfc-00b9-429c-97e5-8e0c34b68be7', '6387e559-9772-4668-9861-847f38251729', 'db71854d-7137-48c8-82ac-6300cdc2cfca', '664619fd-b8b7-40dd-8e97-38ffbe156b78', 'a2e596ec-9c57-4c16-8600-1bf24c703e3b', '611e7a4e-a8f8-4d52-b293-f6c865031f6d', 'd2cbfaf9-4a11-4630-9709-5571ae3798eb', '0401125e-ce04-42e5-90de-2af5b5ab24e5', 'b7d130f6-9ca4-40b6-b54d-545995a0d539', '304ca08d-5d49-4a2e-8406-8330271c3962', '26cb678e-44a5-4a3f-b544-f1001b0356df', '7e54a436-6568-45b5-8872-d22e5018c002', '624ef3a7-08ba-4aec-b3d8-4da16c1a6f3d', '448d3bed-167b-46fd-abb9-ea8c82e70048', '57f0a5c9-67ae-4936-a09e-2eb3bd9a021c', 'cbecd059-5a48-4f0b-bdb6-59a8b3730ef2', 'c7b81747-6a81-431e-806c-5c9c15cc8b6d', 'e26fedb7-cc94-4c8f-979a-2467b89f25d0', 'fcb50e82-a13c-4b08-91cb-7781bc1efff8', '936d9df0-21ac-4f64-987b-8d7ca43f5884', '6243203c-6f75-4dd3-a2a9-015fb6b38ad2', 'b35d9d8f-deed-4209-b065-c65b7742c9ae', '3fd1e4b1-b739-4cca-ac3a-6e6bee949ccc', 'a65d3efe-47af-4717-93e8-eb94f9f961e8', '26c4311d-0741-4a66-8200-f7d7edd6bf56', 'f86c4840-85f5-4109-a53d-3c8aec5a8ca8', '34159f57-4cd9-496b-86d0-31c259e69370', '0ed5783c-323a-46ef-9ae3-1e4e18281ff6', '7905eb9c-cdcf-401d-9f61-969e3732f648', '30fbac9f-107c-4f93-9a49-9e8c676dca32', '5bfee2ae-e092-442a-ac40-4e2a9643451f', 'e3ee58e7-33db-4498-930b-8a1c8301019a', '345b05bf-e6ca-4674-b252-548019571438', 'eb3bbc41-33a4-4344-8152-552f0423f400', 'dada92f4-f0a6-48f3-9158-84563008c6d9', 'c03076ad-0f53-4d42-923b-54141fe4347e', 'a1af8e79-9712-4c55-b1e9-1fe4699bd8c9', '7c9a7b87-afdd-4696-9449-0ba676e3875d', 'f72e9f4d-3410-44d6-9aa9-3effac1d8626', '0b8e82eb-5068-4c75-9dbf-fbdea460d7bc', '78cc6b24-2630-421b-9c1a-e1c138ab7d76', '1598ed95-3744-4add-910a-bc3195847ade', '616b095c-8e39-4037-a301-0aeda912185c', '2836d530-f4f9-4917-9cd8-7294e5dda2f6', '6f7cb30d-191a-4d45-a7c9-6bf54d3ca600', '71f8acff-0403-4a90-ae7e-b5a563f4931b', '48d9e3a2-e46a-45f2-a84f-b34e7a20a3a8', '05b3aefb-fb62-4ffd-90f0-fd019a0d4c3e', '8ab0b9d3-ad6a-4ef3-8636-1500a5b0a3ab', '6392175a-b0aa-4164-941c-6ae70bc4d992', '78dc827c-e9c8-4fb3-8ee7-4f08d4a5d5a3', '09aa3a1a-e078-40c4-82a2-e7c64beafef3', '4e4e1c73-fe6a-4f65-8cc3-971030d1cbe7', 'f8bc66a5-b249-4731-84e5-c9506aa48161', 'f0ac3851-5a40-4fa9-bc30-1458f5db3e66', '68fdbfa2-4a64-480c-b93c-479208ce0f67', '18e358ea-bfbe-490d-91dd-7d1b5de7965e', '079d63fd-2119-4181-8c4a-fe2ed7af343d']

# %%
len(users)
# Out:
# 1000

# %%
MIN_TEMPERATURE = 97
MAX_TEMPERATURE = 103

MIN_AGE = 1
NEW_BORN_AGE = 5
ADOLESCENT_AGE = 15

MIN_WEIGHT = 4
MAX_WEIGHT = 120

MIN_HEIGHT = 50
MAX_HEIGHT = 200

MORNING_HOUR = 6
NOON_HOUR = 12
EVENING_HOUR = 18

MAX_STEP_COUNT = 30_000

MAX_CALORIES_BURNT = 3_000

MIN_HEART_RATE = 50
MAX_HEART_RATE = 150

MIN_SYS_BP = 50
MAX_SYS_BP = 90

MIN_DIA_BP = 100
MAX_DIA_BP = 140

MIN_BREATH_FREQUENCY = 10

MIN_O2_AVG = 90

event_data = {}
for idx, user_id in enumerate(users):
    
    user = {}

    user['user_id'] = str(uuid.uuid4())

    name = fake.name()
    user['firstname'] = name.split(' ')[0]
    user['lastname'] = name.split(' ')[1]

    random_no = secrets.randbelow(2)
    gender = 'male' if random_no == 1 else 'female'
    user['gender'] = gender

    age = MIN_AGE + secrets.randbelow(65)
    user['age'] = age
    
    if age < NEW_BORN_AGE:
        weight = MIN_WEIGHT + secrets.randbelow(10)
        height = MIN_HEIGHT + secrets.randbelow(40)
        
    elif NEW_BORN_AGE <= age <= ADOLESCENT_AGE:
        weight = 20 + secrets.randbelow(20)
        height = 70 + secrets.randbelow(60)
        
    elif age > ADOLESCENT_AGE:
        weight = 40 + secrets.randbelow(80)
        height = 140 + secrets.randbelow(60)

    user['weight'] = weight
    user['height'] = height

    # pick random number of time intervals (1,10)
    intervals_count = 1 + secrets.randbelow(10)

    # pick random number of time frames between start and end date for all intervals
    for interval in range(intervals_count):
        interval_recordings = secrets.randbelow(30)

        start_date = datetime(2022, 8, 1)
        end_date = datetime(2022, 12, 31)

        first_ts = fetch_random_date(start_date, end_date)
        event_ts = first_ts
        
        hour_of_the_day = event_ts.hour
        
        if hour_of_the_day <= MORNING_HOUR:
            stepCount = secrets.randbelow(500)
            caloriesBurnt = secrets.randbelow(200)
            
        elif hour_of_the_day > MORNING_HOUR and hour_of_the_day <= NOON_HOUR:
            stepCount = secrets.randbelow(8000)
            caloriesBurnt = secrets.randbelow(800)
            
        elif hour_of_the_day > NOON_HOUR and hour_of_the_day <= EVENING_HOUR:
            stepCount = secrets.randbelow(15_000)
            caloriesBurnt = secrets.randbelow(1500)
            
        elif hour_of_the_day > EVENING_HOUR:
            stepCount = secrets.randbelow(MAX_STEP_COUNT)
            caloriesBurnt = secrets.randbelow(MAX_CALORIES_BURNT)

        sleepHours = 4 + secrets.randbelow(6)
        
        REMsleepHours = secrets.randbelow(4)
        
        bodyTemperature = 98 + secrets.randbelow(3)
        
        for recording in range(interval_recordings):
            event = {}
            
            event['user'] = user
            
            min_increment = 1
            additional_mins = (min_increment + secrets.randbelow(5))
            additional_sec = secrets.randbelow(30)
            event_ts = event_ts + timedelta(minutes=additional_mins, seconds=additional_sec)
            
            event['eventTimestamp'] = event_ts
            
            random_no = secrets.randbelow(2)
            source = 'app' if random_no == 1 else 'manual'
            event['dataSource'] = source
            
            event_id = str(uuid.uuid4())
            event['eventId'] = event_id
            
            vitals = {}
            
            heartRate = MIN_HEART_RATE + secrets.randbelow(100)
            vitals['heartRate'] = heartRate
            
            systolicBloodPressure = MIN_SYS_BP + secrets.randbelow(40)
            vitals['systolicBloodPressure'] = systolicBloodPressure
            
            diastolicBloodPressure = MIN_DIA_BP + secrets.randbelow(40)
            vitals['diastolicBloodPressure'] = diastolicBloodPressure
            
            random_sign = secrets.randbelow(2)
            random_sign = random_sign if random_sign == 1 else -1
            bodyTemperature += random_sign * round(random.random(), 2)
            bodyTemperature = round(bodyTemperature, 2)
            if bodyTemperature <= MIN_TEMPERATURE:
                bodyTemperature = MIN_TEMPERATURE
            elif bodyTemperature >= MAX_TEMPERATURE:
                bodyTemperature = MAX_TEMPERATURE
            vitals['bodyTemperature'] = bodyTemperature

            breathingFrequency = MIN_BREATH_FREQUENCY + secrets.randbelow(12)
            vitals['breathingFrequency'] = breathingFrequency

            event['vitals'] = vitals
            
            generalHealthStats = {}
            
            min_increment = secrets.randbelow(10)
            additional_steps = (min_increment + secrets.randbelow(100))
            
            stepCount = stepCount + additional_steps
            
            generalHealthStats['stepCount'] = stepCount

            bloodOxygenAvg = MIN_O2_AVG + secrets.randbelow(10)
            generalHealthStats['bloodOxygenAvg'] = bloodOxygenAvg

            stress = secrets.randbelow(5)
            generalHealthStats['stress'] = stress

            generalHealthStats['sleepHours'] = sleepHours

            generalHealthStats['REMsleepHours'] = REMsleepHours

            min_increment = secrets.randbelow(20)
            additional_calories = (min_increment + secrets.randbelow(200))
            caloriesBurnt = caloriesBurnt + additional_calories
            
            generalHealthStats['caloriesBurnt'] = caloriesBurnt

            event['generalHealthStats'] = generalHealthStats
            
            event_data[f'{event_id}'] = event

# %%
df_records = pd.DataFrame(event_data).T.reset_index(drop=True)
df_records = pd.concat([df_records, 
                        df_records['generalHealthStats'].apply(lambda x: pd.Series(x)), 
                        df_records['user'].apply(lambda x: pd.Series(x)), 
                        df_records['vitals'].apply(lambda x: pd.Series(x))
                       ], axis=1)

# %%
cols = [col for col in df_records.columns if col not in ['user', 'vitals', 'generalHealthStats']]
df_records[cols].head(5)
# Out:
#        eventTimestamp dataSource                               eventId  \
# 0 2022-09-14 00:35:01        app  a7229f9d-5472-4d4d-8454-1dd7642aaf53
# 1 2022-09-14 00:38:30     manual  c005dd44-a503-4327-be9f-a36d9a772d74
# 2 2022-09-14 00:42:54     manual  cbfa75d9-9867-458c-a295-9178de717052
# 3 2022-09-14 00:46:06     manual  3c33ee7d-ffcf-4ced-ab6a-8263001db2e2
# 4 2022-09-14 00:51:14     manual  e4dd5a54-c297-4c2a-b6f8-428b0f9a2db5
#
#    stepCount  bloodOxygenAvg  stress  sleepHours  REMsleepHours  \
# 0        366              97       0           8              1
# 1        377              92       3           8              1
# 2        402              91       2           8              1
# 3        476              94       4           8              1
# 4        496              98       2           8              1
#
#    caloriesBurnt                               user_id  ...  lastname  gender  \
# ...

# %%
df_records.columns
# Out:
# Index(['user', 'eventTimestamp', 'dataSource', 'eventId', 'vitals',
#        'generalHealthStats', 'stepCount', 'bloodOxygenAvg', 'stress',
#        'sleepHours', 'REMsleepHours', 'caloriesBurnt', 'user_id', 'firstname',
#        'lastname', 'gender', 'age', 'weight', 'height', 'heartRate',
#        'systolicBloodPressure', 'diastolicBloodPressure', 'bodyTemperature',
#        'breathingFrequency'],
#       dtype='object')

# %%
df_records.to_csv('time_series_dump.csv')

# %%
df = df_records.copy()

# %% [markdown]
# ## Sample

# %%
df_records.to_dict('records')[0]
# Out:
# {'user': {'user_id': 'b53cebe1-d8ee-4479-881a-f94019e991e4',
#   'firstname': 'Angela',
#   'lastname': 'Wright',
#   'gender': 'female',
#   'age': 6,
#   'weight(kg)': 33,
#   'height(cm)': 112},
#  'eventTimestamp': Timestamp('2022-12-26 10:58:33'),
#  'dataSource': 'manual',
#  'eventId': '2b23b326-3a6c-41ea-b617-994dae4d6c3f',
#  'vitals': {'heartRate(bpm)': 66,
#   'systolicBloodPressure(mmHg)': 85,
#   'diastolicBloodPressure(mmHg)': 111,
#   'bodyTemperature(F)': 98.81,
#   'breathingFrequency(perminute)': 12},
#  'generalHealthStats': {'stepCount(cumulativeforday)': 3605,
#   'bloodOxygenAvg(mmHg)': 99,
#   'stress(0to5)': 3,
#   'sleepHours': 7,
#   'REMsleepHours': 3,
#   'caloriesBurnt(cumulativeforday)': 822},
#  'stepCount(cumulativeforday)': 3605,
#  'bloodOxygenAvg(mmHg)': 99,
#  'stress(0to5)': 3,
#  'sleepHours': 7,
#  'REMsleepHours': 3,
#  'caloriesBurnt(cumulativeforday)': 822,
#  'user_id': 'b53cebe1-d8ee-4479-881a-f94019e991e4',
#  'firstname': 'Angela',
# ...

# %% [markdown]
# # Vitals

# %%
vital_cols = ['heartRate(bpm)', 'systolicBloodPressure(mmHg)', 'diastolicBloodPressure(mmHg)', 'bodyTemperature(F)', 
              'breathingFrequency(perminute)']

# %%
df['healthState'] = ''
lower_bound = 0.05
upper_bound = 0.95

# %%
df.loc[(df['heartRate(bpm)'] <= df['heartRate(bpm)'].quantile(lower_bound)) | (df['heartRate(bpm)'] >= df['heartRate(bpm)'].quantile(upper_bound))
       | (df['systolicBloodPressure(mmHg)'] <= df['systolicBloodPressure(mmHg)'].quantile(lower_bound)) | (df['systolicBloodPressure(mmHg)'] >= df['systolicBloodPressure(mmHg)'].quantile(upper_bound))
       | (df['diastolicBloodPressure(mmHg)'] <= df['diastolicBloodPressure(mmHg)'].quantile(lower_bound)) | (df['diastolicBloodPressure(mmHg)'] >= df['diastolicBloodPressure(mmHg)'].quantile(upper_bound))
       | (df['bodyTemperature(F)'] < df['bodyTemperature(F)'].quantile(lower_bound)) | (df['bodyTemperature(F)'] > df['bodyTemperature(F)'].quantile(upper_bound))
       | (df['breathingFrequency(perminute)'] <= df['breathingFrequency(perminute)'].quantile(lower_bound)) | (df['breathingFrequency(perminute)'] >= df['breathingFrequency(perminute)'].quantile(upper_bound))
       , 'healthState'] = 'bad'

df.loc[df['healthState'] == '', 'healthState'] = 'good'

df['healthState'].value_counts()
# Out:
# good    42796
# bad     38938
# Name: healthState, dtype: int64

# %%
df[vital_cols].head()
# Out:
#    heartRate(bpm)  systolicBloodPressure(mmHg)  diastolicBloodPressure(mmHg)  \
# 0            66.0                         85.0                         111.0
# 1            89.0                         72.0                         117.0
# 2           123.0                         87.0                         110.0
# 3            83.0                         89.0                         130.0
# 4            77.0                         80.0                         109.0
#
#    bodyTemperature(F)  breathingFrequency(perminute)
# 0               98.81                           12.0
# 1               99.63                           13.0
# 2               99.82                           17.0
# 3               98.85                           20.0
# 4               99.29                           19.0

# %%
df['heartRate(bpm)'].quantile(lower_bound), df['heartRate(bpm)'].quantile(upper_bound)
# Out:
# (55.0, 145.0)

# %%
df['systolicBloodPressure(mmHg)'].quantile(lower_bound), df['systolicBloodPressure(mmHg)'].quantile(upper_bound)
# Out:
# (52.0, 87.0)

# %%
df['diastolicBloodPressure(mmHg)'].quantile(lower_bound), df['diastolicBloodPressure(mmHg)'].quantile(upper_bound)
# Out:
# (102.0, 138.0)

# %%
df['bodyTemperature(F)'].quantile(lower_bound), df['bodyTemperature(F)'].quantile(upper_bound)
# Out:
# (97.0, 102.2)

# %%
df['breathingFrequency(perminute)'].quantile(lower_bound), df['breathingFrequency(perminute)'].quantile(upper_bound)
# Out:
# (10.0, 21.0)

# %%
df[df['healthState'] == 'bad'][vital_cols].sample(8)
# Out:
#        heartRate(bpm)  systolicBloodPressure(mmHg)  \
# 48765            76.0                         64.0
# 47583            78.0                         69.0
# 18668           108.0                         89.0
# 3943             92.0                         55.0
# 62859           108.0                         84.0
# 28501           143.0                         88.0
# 36283            76.0                         61.0
# 1942             78.0                         79.0
#
#        diastolicBloodPressure(mmHg)  bodyTemperature(F)  \
# 48765                         111.0              102.93
# 47583                         100.0               97.00
# 18668                         125.0               98.87
# 3943                          103.0               98.70
# 62859                         120.0               99.61
# 28501                         108.0               98.02
# 36283                         130.0               98.19
# ...

# %%
df[df['healthState'] == 'good'][vital_cols].sample(8)
# Out:
#        heartRate(bpm)  systolicBloodPressure(mmHg)  \
# 55926           131.0                         74.0
# 12914            77.0                         66.0
# 49360           122.0                         61.0
# 3421            108.0                         86.0
# 34920           100.0                         68.0
# 46167            95.0                         72.0
# 78614           107.0                         81.0
# 1243             59.0                         71.0
#
#        diastolicBloodPressure(mmHg)  bodyTemperature(F)  \
# 55926                         117.0               98.81
# 12914                         116.0               98.89
# 49360                         122.0               97.67
# 3421                          123.0               98.37
# 34920                         122.0               99.61
# 46167                         124.0              101.87
# 78614                         126.0              102.10
# ...

# %%
df.to_csv('time_series_dump_v1.csv')
